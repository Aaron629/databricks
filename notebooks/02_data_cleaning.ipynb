# %%
# Code from 01_demo_etl
data = [
    ("001", "Alice", "A", 100, "2024-01-01"),
    ("002", "Bob", None, 200, "2024-01-02"),
    ("003", "Cathy", "B", None, "2024-01-03"),
    ("004", None, "A", 150, "2024-01-04"),
]

df = spark.createDataFrame(data, ["order_id", "customer", "category", "amount", "date"])
df.show()

# Data cleaning
df_clean = df.dropDuplicates()

df.show()

df_clean.show()
