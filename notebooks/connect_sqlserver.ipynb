# %%
jdbc_url = "jdbc:sqlserver://GDCDB2:1433;databaseName=BI_STG_CRP;encrypt=true;trustServerCertificate=true"

properties = {
    "user": "LFRCRP",
    "password": "2yp3pbwm",
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

df = spark.read.jdbc(
    url=jdbc_url,
    table="dbo.DMS_DATA_DIVIDE",
    properties=properties
)

display(df)
